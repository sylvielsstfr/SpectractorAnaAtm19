# %%
version()
# Out:
# 'SageMath version 8.7, Release Date: 2019-03-23'

# %%
# %display latex

# %%
x=var("x",latex_name="x")
D=var("D",latex_name="D")
a=var("a",latex_name="a")
lbd=var("ldb",latex_name="\\lambda")

# %%
f = function('f')

# %%
f(x)=D*tan(arcsin(x/a))

# %%
a=1./150. *1000000 # nm

# %%
D=200.  #mm

# %%
f(x)=D*tan(arcsin(x/a))

# %%
f
# Out:
# x |--> 0.0300000000000000*x/sqrt(-(2.25000000000000e-8)*x^2 + 1)

# %%
plot(f(x),(x,0,1000.),gridlines=True,frame=True,title="Holo Dispersion",axes_labels=['$\\lambda$ (nm)','$x$ (mm)'])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot?

# %%
g(x)=diff(f,x)

# %%
g
# Out:
# x |--> (6.75000000000000e-10)*x^2/(-(2.25000000000000e-8)*x^2 + 1)^(3/2) + 0.0300000000000000/sqrt(-(2.25000000000000e-8)*x^2 + 1)

# %%
plot(g(x),x,0,1000.,gridlines=True,title="Dispersion per wavelength",frame=True,axes_labels=['$\\lambda$ (nm)','$dx/d\\lambda$ mm/nm '])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
13.5*2048/1000.*sqrt(2).n()
# Out:
# 39.1001765724913
